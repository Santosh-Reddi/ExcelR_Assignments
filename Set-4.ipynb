# %% [markdown]
# # Q3

# %%
Mu=50
Si=40
n=100

# %%
#!pip install scipy
from scipy import stats
# Out:
# ...
#      ---------------------------------------- 36.9/36.9 MB 7.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.7/14.7 MB 9.5 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\santo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np

# %%
k=(stats.norm.cdf(55,Mu,Si/np.sqrt(n))-stats.norm.cdf(45,Mu,Si/np.sqrt(n))) # probability sample mean to lie between 45 to 55
(1-k)*100  # Probability that investigation happen (happend when mean isn't between 45 to 55)
# Out:
# 21.129954733371072

# %% [markdown]
# # Q4

# %%
p=(Si*stats.norm.ppf(0.975))/(55-Mu)

# %%
n=p*p
print("",round(n))
# Out:
#  246

# %%
#250 is closer to 246. Hence 250 is the minimum sample size needed to maintain investigation probability to 5%.

# %% [markdown]
# # Q5

# %%
120/np.sqrt(40000)
# Out:
# 0.6
